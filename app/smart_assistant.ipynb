# %% [markdown]
# # Smart Query Assistant

# %%
import logging
from dotenv import load_dotenv

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')

load_dotenv()

from smart_assistant import SmartAssistant
from llm_service import LLMService

llm_service = LLMService()
print(f"Using LLM provider: {llm_service.provider}")
# Out:
# Using LLM provider: claude

# %%
# Initialize the SmartAssistant (no database connection for now)
assistant = SmartAssistant(
    llm_service=llm_service,
    yaml_file_path="verified_queries.yaml",
    debug_mode=True
)

# Display the loaded verified queries
print(f"Verified queries:")
for i, query in enumerate(assistant.verified_queries):
    print(f"\n{i+1}. {query.get('name')}")
    print(f"   Question: {query.get('question')}")
# Out:
# 2025-04-28 13:54:28,474 - root - INFO - Loaded 5 verified queries from verified_queries.yaml
# 2025-04-28 13:54:28,475 - root - INFO - Loaded 5 verified queries
# Verified queries:
#
# 1. Top Performing Agencies by Premium
#    Question: Which agencies generate the most premium?
#
# 2. Distribution Channel Performance Analysis
#    Question: How are our different distribution channels performing?
#
# 3. Agent Performance Report
#    Question: How are our agents performing in terms of sales?
#
# 4. Claims Analysis by Policy Type
#    Question: What are our loss ratios by policy type?
#
# 5. Regional Agency Performance
#    Question: How are our agencies performing by region?

# %%
test_question = "Which agencies in the Northeast region generate the most premium?"

# %%
print(f"Testing question: '{test_question}'")
match_info = assistant.find_matching_query(test_question)

if match_info:
    print("\nMatch found!")
    print(f"Matched query: {match_info['verified_query'].get('name')}")
    print(f"Similarity: {match_info['similarity']}%")
    print(f"Needs modification: {match_info['modification_needed']}")
    if match_info['modification_needed']:
        print(f"Modifications: {match_info['modifications']}")
        
        # Try adjusting the SQL
        original_sql = match_info['verified_query'].get('sql', '')
        print("\nOriginal SQL:")
        print(original_sql)
        
        adjusted_sql = assistant.adjust_sql(original_sql, match_info['modifications'])
        print("\nAdjusted SQL:")
        print(adjusted_sql)
else:
    print("\nNo match found. Debugging required.")
# Out:
# 2025-04-28 13:51:57,229 - root - INFO - Created prompt with 5 queries
# 2025-04-28 13:51:57,230 - root - DEBUG - Full queries text: Query 1:
# Name: Top Performing Agencies by Premium
# Question: Which agencies generate the most premium?
# SQL: SELECT
#   a.agency_id,
#   a.agency_name,
#   a.region,
#   a.tier,
#   SUM(p.premium_amount) AS total_premium
# FROM
#   agencies a
#   JOIN agents ag ON a.agency_id = ag.agency_id
#   JOIN policies p ON ag.agent_id = p.agent_id
# WHERE
#   p.status = 'active' -- active, lapsed, cancelled
# GROUP BY
#   a.agency_id, a.agency_name, a.region, a.tier
# ORDER BY
#   total_premium DESC
# LIMIT 10;
#
# Explanation: This query calculates the total premium amount generated by each agency. It joins the agencies, agents, and policies tables to aggregate premium amounts for active policies, then sorts them by total premium in descending order.
#
# Query 2:
# Name: Distribution Channel Performance Analysis
# Question: How are our different distribution channels performing?
# SQL: SELECT
#   dc.channel_id,
#   dc.channel_name,
#   dc.channel_type,
#   COUNT(p.policy_id) AS policy_count,
#   SUM(p.premium_amount) AS total_premium,
#   AVG(p.premium_amount) AS avg_premium_per_policy,
#   SUM(p.premium_amount * dc.commission_rate / 100) AS estimated_commission
# FROM
#   distribution_channels dc
#   JOIN policies p ON dc.channel_id = p.channel_id
# WHERE
#   p.status = 'active' -- active, lapsed, cancelled
# GROUP BY
#   dc.channel_id, dc.channel_name, dc.channel_type
# ORDER BY
#   total_premium DESC;
#
# Explanation: This query analyzes the performance of different distribution channels by measuring total premium, policy count, and average premium per policy for each channel. Only active policies are included, and the results are ordered by total premium.
#
# Query 3:
# Name: Agent Performance Report
# Question: How are our agents performing in terms of sales?
# SQL: SELECT
#   ag.agent_id,
#   ag.agent_name,
#   a.agency_name,
#   ag.certification_level,
#   COUNT(p.policy_id) AS policies_sold,
#   SUM(p.premium_amount) AS total_premium,
#   SUM(p.annual_revenue_impact) AS total_revenue_impact
# FROM
#   agents ag
#   JOIN agencies a ON ag.agency_id = a.agency_id
#   JOIN policies p ON ag.agent_id = p.agent_id
# WHERE
#   ag.status = 'active' -- active, inactive
#   AND p.status = 'active' -- active, lapsed, cancelled
# GROUP BY
#   ag.agent_id, ag.agent_name, a.agency_name, ag.certification_level
# ORDER BY
#   total_premium DESC;
#
# Explanation: This query provides a performance report for agents, including their agency, certification level, number of policies sold, total premium, and revenue impact. It only includes active agents and their active policies.
#
# Query 4:
# Name: Claims Analysis by Policy Type
# Question: What are our loss ratios by policy type?
# SQL: SELECT
#   p.policy_type,
#   COUNT(p.policy_id) AS policy_count,
#   SUM(p.premium_amount) AS total_premium,
#   COUNT(c.claim_id) AS claim_count,
#   SUM(c.claim_amount) AS total_claim_amount,
#   AVG(c.claim_amount) AS avg_claim_amount,
#   COUNT(c.claim_id)::float / COUNT(p.policy_id) AS claim_frequency,
#   CASE
#     WHEN SUM(p.premium_amount) > 0 THEN
#       SUM(c.claim_amount) / SUM(p.premium_amount) * 100
#     ELSE 0
#   END AS loss_ratio_percent
# FROM
#   policies p
#   LEFT JOIN claims c ON p.policy_id = c.policy_id
# WHERE
#   p.status = 'active' -- active, lapsed, cancelled
# GROUP BY
#   p.policy_type
# ORDER BY
#   loss_ratio_percent DESC;
#
# Explanation: This query analyzes claims data grouped by policy type, showing total claim amount, average claim amount, claim frequency, and loss ratio. The loss ratio is calculated as (total claim amount / total premium) for each policy type.
#
# Query 5:
# Name: Regional Agency Performance
# Question: How are our agencies performing by region?
# SQL: SELECT
#   a.region,
#   COUNT(DISTINCT a.agency_id) AS agency_count,
#   SUM(p.premium_amount) AS total_premium,
#   SUM(p.premium_amount) / COUNT(DISTINCT a.agency_id) AS avg_premium_per_agency,
#   COUNT(p.policy_id) AS policy_count
# FROM
#   agencies a
#   JOIN agents ag ON a.agency_id = ag.agency_id
#   JOIN policies p ON ag.agent_id = p.agent_id
# WHERE
#   p.status = 'active' -- active, lapsed, cancelled
# GROUP BY
#   a.region
# ORDER BY
#   total_premium DESC;
#
# Explanation: This query analyzes agency performance by region, showing the number of agencies, average premium per agency, total premium, and policy count for each region. The results are sorted by total premium in descending order.
#
#
# 2025-04-28 13:51:57,230 - root - INFO - Sending request to LLM service...
# 2025-04-28 13:51:57,233 - anthropic._base_client - DEBUG - Request options: {'method': 'post', 'url': '/v1/messages', 'timeout': Timeout(connect=5.0, read=600, write=600, pool=600), 'files': None, 'idempotency_key': 'stainless-python-retry-ef4f37cc-c360-4224-983a-e6a907a69325', 'json_data': {'max_tokens': 2000, 'messages': [{'role': 'user', 'content': 'Follow these comparison rules carefully:\n1. Core Query Components:\n   - What is being counted/summed/averaged?\n   - Which time period is being queried?\n   - What status or category filters are needed?\n\n2. Pattern Matching:\n   - Match main action (count, sum, etc.)\n   - Match time period (specific year)\n   - Match status (active, inactive, etc.)\n   - Look for status values in SQL comments\n\n3. Modification Requirements:\n   - List ALL required changes in modifications\n   - Include both year AND status changes when needed\n   - Be explicit about which status value to use\n   - Use values from SQL comments when available\n\nReturn a JSON with these fields:\n- "match": boolean indicating if a match was found\n- "query_number": integer with the matching query number\n- "similarity": integer percentage of similarity (0-100)\n- "modification_needed": boolean indicating if changes are needed\n- "modifications": string describing needed changes if any\n\nExample modifications:\n- Multiple changes: "Change year from 2023 to 2022 in WHERE clause AND update policy_status from \'active\' to \'lapsed\' (value from comment)"\n- Status only: "Update status from \'active\' to \'inactive\' using value from comment"\n- Year only: "Change year from 2023 to 2022 in WHERE clause"\n\nUser Question: Which agencies in the Northeast region generate the most premium?\n\nPreviously verified queries:\nQuery 1:\nName: Top Performing Agencies by Premium\nQuestion: Which agencies generate the most premium?\nSQL: SELECT \n  a.agency_id,\n  a.agency_name,\n  a.region,\n  a.tier,\n  SUM(p.premium_amount) AS total_premium\nFROM \n  agencies a\n  JOIN agents ag ON a.agency_id = ag.agency_id\n  JOIN policies p ON ag.agent_id = p.agent_id\nWHERE \n  p.status = \'active\' -- active, lapsed, cancelled\nGROUP BY \n  a.agency_id, a.agency_name, a.region, a.tier\nORDER BY \n  total_premium DESC\nLIMIT 10;\n\nExplanation: This query calculates the total premium amount generated by each agency. It joins the agencies, agents, and policies tables to aggregate premium amounts for active policies, then sorts them by total premium in descending order.\n\nQuery 2:\nName: Distribution Channel Performance Analysis\nQuestion: How are our different distribution channels performing?\nSQL: SELECT \n  dc.channel_id,\n  dc.channel_name,\n  dc.channel_type,\n  COUNT(p.policy_id) AS policy_count,\n  SUM(p.premium_amount) AS total_premium,\n  AVG(p.premium_amount) AS avg_premium_per_policy,\n  SUM(p.premium_amount * dc.commission_rate / 100) AS estimated_commission\nFROM \n  distribution_channels dc\n  JOIN policies p ON dc.channel_id = p.channel_id\nWHERE \n  p.status = \'active\' -- active, lapsed, cancelled\nGROUP BY \n  dc.channel_id, dc.channel_name, dc.channel_type\nORDER BY \n  total_premium DESC;\n\nExplanation: This query analyzes the performance of different distribution channels by measuring total premium, policy count, and average premium per policy for each channel. Only active policies are included, and the results are ordered by total premium.\n\nQuery 3:\nName: Agent Performance Report\nQuestion: How are our agents performing in terms of sales?\nSQL: SELECT \n  ag.agent_id,\n  ag.agent_name,\n  a.agency_name,\n  ag.certification_level,\n  COUNT(p.policy_id) AS policies_sold,\n  SUM(p.premium_amount) AS total_premium,\n  SUM(p.annual_revenue_impact) AS total_revenue_impact\nFROM \n  agents ag\n  JOIN agencies a ON ag.agency_id = a.agency_id\n  JOIN policies p ON ag.agent_id = p.agent_id\nWHERE \n  ag.status = \'active\' -- active, inactive\n  AND p.status = \'active\' -- active, lapsed, cancelled\nGROUP BY \n  ag. ...
# 2025-04-28 13:51:57,234 - anthropic._base_client - DEBUG - Sending HTTP Request: POST https://api.anthropic.com/v1/messages
# 2025-04-28 13:51:57,234 - httpcore.connection - DEBUG - connect_tcp.started host='api.anthropic.com' port=443 local_address=None timeout=5.0 socket_options=[(65535, 8, True), (6, 257, 60), (6, 258, 5)]
# Testing question: 'Which agencies in the Northeast region generate the most premium?'
# 2025-04-28 13:51:57,436 - httpcore.connection - DEBUG - connect_tcp.complete return_value=<httpcore._backends.sync.SyncStream object at 0x10fcbee90>
# 2025-04-28 13:51:57,437 - httpcore.connection - DEBUG - start_tls.started ssl_context=<ssl.SSLContext object at 0x10f9f7ad0> server_hostname='api.anthropic.com' timeout=5.0
# 2025-04-28 13:51:57,459 - httpcore.connection - DEBUG - start_tls.complete return_value=<httpcore._backends.sync.SyncStream object at 0x1068fa3d0>
# 2025-04-28 13:51:57,459 - httpcore.http11 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-28 13:51:57,460 - httpcore.http11 - DEBUG - send_request_headers.complete
# 2025-04-28 13:51:57,461 - httpcore.http11 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-28 13:51:57,461 - httpcore.http11 - DEBUG - send_request_body.complete
# 2025-04-28 13:51:57,461 - httpcore.http11 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# 2025-04-28 13:51:58,423 - httpcore.http11 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Mon, 28 Apr 2025 18:51:58 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'anthropic-ratelimit-input-tokens-limit', b'50000'), (b'anthropic-ratelimit-input-tokens-remaining', b'49000'), (b'anthropic-ratelimit-input-tokens-reset', b'2025-04-28T18:51:59Z'), (b'anthropic-ratelimit-output-tokens-limit', b'10000'), (b'anthropic-ratelimit-output-tokens-remaining', b'10000'), (b'anthropic-ratelimit-output-tokens-reset', b'2025-04-28T18:51:58Z'), (b'anthropic-ratelimit-requests-limit', b'50'), (b'anthropic-ratelimit-requests-remaining', b'49'), (b'anthropic-ratelimit-requests-reset', b'2025-04-28T18:51:58Z'), (b'anthropic-ratelimit-tokens-limit', b'60000'), (b'anthropic-ratelimit-tokens-remaining', b'59000'), (b'anthropic-ratelimit-tokens-reset', b'2025-04-28T18:51:58Z'), (b'request-id', b'req_011CNbdmZ1X1JiD5Qfd8sYxz'), (b'anthropic-organization-id', b'23fe48df-acf6-4bd8-91d1-68b1891dc7a2'), (b'via', b'1.1 google'), (b'cf-cache-status', b'DYNAMIC'), (b'X-Robots-Tag', b'none'), (b'Server', b'cloudflare'), (b'CF-RAY', b'9378c10459feeb69-ORD'), (b'Content-Encoding', b'gzip')])
# 2025-04-28 13:51:58,424 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-04-28 13:51:58,425 - httpcore.http11 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-28 13:51:58,425 - httpcore.http11 - DEBUG - receive_response_body.complete
# 2025-04-28 13:51:58,426 - httpcore.http11 - DEBUG - response_closed.started
# 2025-04-28 13:51:58,426 - httpcore.http11 - DEBUG - response_closed.complete
# 2025-04-28 13:51:58,426 - anthropic._base_client - DEBUG - HTTP Response: POST https://api.anthropic.com/v1/messages "200 OK" Headers({'date': 'Mon, 28 Apr 2025 18:51:58 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'anthropic-ratelimit-input-tokens-limit': '50000', 'anthropic-ratelimit-input-tokens-remaining': '49000', 'anthropic-ratelimit-input-tokens-reset': '2025-04-28T18:51:59Z', 'anthropic-ratelimit-output-tokens-limit': '10000', 'anthropic-ratelimit-output-tokens-remaining': '10000', 'anthropic-ratelimit-output-tokens-reset': '2025-04-28T18:51:58Z', 'anthropic-ratelimit-requests-limit': '50', 'anthropic-ratelimit-requests-remaining': '49', 'anthropic-ratelimit-requests-reset': '2025-04-28T18:51:58Z', 'anthropic-ratelimit-tokens-limit': '60000', 'anthropic-ratelimit-tokens-remaining': '59000', 'anthropic-ratelimit-tokens-reset': '2025-04-28T18:51:58Z', 'request-id': 'req_011CNbdmZ1X1JiD5Qfd8sYxz', 'anthropic-organization-id': '23fe48df-acf6-4bd8-91d1-68b1891dc7a2', 'via': '1.1 google', 'cf-cache-status': 'DYNAMIC', 'x-robots-tag': 'none', 'server': 'cloudflare', 'cf-ray': '9378c10459feeb69-ORD', 'content-encoding': 'gzip'})
# 2025-04-28 13:51:58,427 - anthropic._base_client - DEBUG - request_id: req_011CNbdmZ1X1JiD5Qfd8sYxz
# 2025-04-28 13:51:58,429 - root - INFO - Received response from LLM service
# 2025-04-28 13:51:58,429 - root - DEBUG - Raw LLM response: {
#   "match": true,
#   "query_number": 5,
#   "similarity": 90,
#   "modification_needed": true,
#   "modifications": "Change region from 'Northeast' to 'Northeast' in WHERE clause"
# }
# 2025-04-28 13:51:58,430 - root - INFO - Match found! Query #5 with 90% similarity
# 2025-04-28 13:51:58,430 - root - WARNING - System prompt file not found: /Users/avenugopal/smart_query_assistant/app/adjust_sql_system_prompt.txt
# 2025-04-28 13:51:58,431 - root - WARNING - User prompt file not found: /Users/avenugopal/smart_query_assistant/app/adjust_sql_user_prompt.txt
# 2025-04-28 13:51:58,431 - root - INFO - Adjusting SQL query
# 2025-04-28 13:51:58,431 - anthropic._base_client - DEBUG - Request options: {'method': 'post', 'url': '/v1/messages', 'timeout': Timeout(connect=5.0, read=600, write=600, pool=600), 'files': None, 'idempotency_key': 'stainless-python-retry-29695d56-e7bb-4d53-81b8-07e611f08410', 'json_data': {'max_tokens': 2000, 'messages': [{'role': 'user', 'content': "Original SQL:\nSELECT \n  a.region,\n  COUNT(DISTINCT a.agency_id) AS agency_count,\n  SUM(p.premium_amount) AS total_premium,\n  SUM(p.premium_amount) / COUNT(DISTINCT a.agency_id) AS avg_premium_per_agency,\n  COUNT(p.policy_id) AS policy_count\nFROM \n  agencies a\n  JOIN agents ag ON a.agency_id = ag.agency_id\n  JOIN policies p ON ag.agent_id = p.agent_id\nWHERE \n  p.status = 'active' -- active, lapsed, cancelled\nGROUP BY \n  a.region\nORDER BY \n  total_premium DESC;\n\n\nModification instructions:\nChange region from 'Northeast' to 'Northeast' in WHERE clause\n\nRules:\n1. Analyze ALL Components:\n   - Column aliases: Update to match the context\n   - SQL Comments: Extract valid status values\n   - WHERE conditions: Year and status filters\n\n2. ONLY modify these parts:\n   - Column aliases in SELECT clause to match the question context\n   - Date/Year in WHERE clause as requested\n   - Status values using options from comments\n\n3. Column Alias Guidelines:\n   - Match the verb from user's question\n   - Keep prefixes if present\n   - Maintain quote style and capitalization\n\n4. Keep Intact:\n   - Query structure\n   - Table names\n   - Aggregation functions\n   - Comment content\n\nReturn only the modified SQL query.\n"}], 'model': 'claude-3-haiku-20240307', 'system': 'You are an expert SQL developer for PostgreSQL. \nYour task is to analyze and modify SQL based on specific requirements.', 'temperature': 0}}
# 2025-04-28 13:51:58,432 - anthropic._base_client - DEBUG - Sending HTTP Request: POST https://api.anthropic.com/v1/messages
# 2025-04-28 13:51:58,432 - httpcore.http11 - DEBUG - send_request_headers.started request=<Request [b'POST']>
# 2025-04-28 13:51:58,433 - httpcore.http11 - DEBUG - send_request_headers.complete
# 2025-04-28 13:51:58,433 - httpcore.http11 - DEBUG - send_request_body.started request=<Request [b'POST']>
# 2025-04-28 13:51:58,433 - httpcore.http11 - DEBUG - send_request_body.complete
# 2025-04-28 13:51:58,434 - httpcore.http11 - DEBUG - receive_response_headers.started request=<Request [b'POST']>
# Match found!
# Matched query: Regional Agency Performance
# Similarity: 90%
# Needs modification: True
# Modifications: Change region from 'Northeast' to 'Northeast' in WHERE clause
#
# Original SQL:
# SELECT
#   a.region,
#   COUNT(DISTINCT a.agency_id) AS agency_count,
#   SUM(p.premium_amount) AS total_premium,
#   SUM(p.premium_amount) / COUNT(DISTINCT a.agency_id) AS avg_premium_per_agency,
#   COUNT(p.policy_id) AS policy_count
# FROM
#   agencies a
#   JOIN agents ag ON a.agency_id = ag.agency_id
#   JOIN policies p ON ag.agent_id = p.agent_id
# WHERE
#   p.status = 'active' -- active, lapsed, cancelled
# GROUP BY
#   a.region
# ORDER BY
#   total_premium DESC;
# 2025-04-28 13:52:00,637 - httpcore.http11 - DEBUG - receive_response_headers.complete return_value=(b'HTTP/1.1', 200, b'OK', [(b'Date', b'Mon, 28 Apr 2025 18:52:00 GMT'), (b'Content-Type', b'application/json'), (b'Transfer-Encoding', b'chunked'), (b'Connection', b'keep-alive'), (b'anthropic-ratelimit-input-tokens-limit', b'50000'), (b'anthropic-ratelimit-input-tokens-remaining', b'49000'), (b'anthropic-ratelimit-input-tokens-reset', b'2025-04-28T18:52:00Z'), (b'anthropic-ratelimit-output-tokens-limit', b'10000'), (b'anthropic-ratelimit-output-tokens-remaining', b'10000'), (b'anthropic-ratelimit-output-tokens-reset', b'2025-04-28T18:52:00Z'), (b'anthropic-ratelimit-requests-limit', b'50'), (b'anthropic-ratelimit-requests-remaining', b'48'), (b'anthropic-ratelimit-requests-reset', b'2025-04-28T18:51:59Z'), (b'anthropic-ratelimit-tokens-limit', b'60000'), (b'anthropic-ratelimit-tokens-remaining', b'59000'), (b'anthropic-ratelimit-tokens-reset', b'2025-04-28T18:52:00Z'), (b'request-id', b'req_011CNbdmd9JpjZUa4Rq2VVCH'), (b'anthropic-organization-id', b'23fe48df-acf6-4bd8-91d1-68b1891dc7a2'), (b'via', b'1.1 google'), (b'cf-cache-status', b'DYNAMIC'), (b'X-Robots-Tag', b'none'), (b'Server', b'cloudflare'), (b'CF-RAY', b'9378c10a6adaeb69-ORD'), (b'Content-Encoding', b'gzip')])
# 2025-04-28 13:52:00,638 - httpx - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-04-28 13:52:00,638 - httpcore.http11 - DEBUG - receive_response_body.started request=<Request [b'POST']>
# 2025-04-28 13:52:00,639 - httpcore.http11 - DEBUG - receive_response_body.complete
# 2025-04-28 13:52:00,639 - httpcore.http11 - DEBUG - response_closed.started
# 2025-04-28 13:52:00,639 - httpcore.http11 - DEBUG - response_closed.complete
# 2025-04-28 13:52:00,639 - anthropic._base_client - DEBUG - HTTP Response: POST https://api.anthropic.com/v1/messages "200 OK" Headers({'date': 'Mon, 28 Apr 2025 18:52:00 GMT', 'content-type': 'application/json', 'transfer-encoding': 'chunked', 'connection': 'keep-alive', 'anthropic-ratelimit-input-tokens-limit': '50000', 'anthropic-ratelimit-input-tokens-remaining': '49000', 'anthropic-ratelimit-input-tokens-reset': '2025-04-28T18:52:00Z', 'anthropic-ratelimit-output-tokens-limit': '10000', 'anthropic-ratelimit-output-tokens-remaining': '10000', 'anthropic-ratelimit-output-tokens-reset': '2025-04-28T18:52:00Z', 'anthropic-ratelimit-requests-limit': '50', 'anthropic-ratelimit-requests-remaining': '48', 'anthropic-ratelimit-requests-reset': '2025-04-28T18:51:59Z', 'anthropic-ratelimit-tokens-limit': '60000', 'anthropic-ratelimit-tokens-remaining': '59000', 'anthropic-ratelimit-tokens-reset': '2025-04-28T18:52:00Z', 'request-id': 'req_011CNbdmd9JpjZUa4Rq2VVCH', 'anthropic-organization-id': '23fe48df-acf6-4bd8-91d1-68b1891dc7a2', 'via': '1.1 google', 'cf-cache-status': 'DYNAMIC', 'x-robots-tag': 'none', 'server': 'cloudflare', 'cf-ray': '9378c10a6adaeb69-ORD', 'content-encoding': 'gzip'})
# 2025-04-28 13:52:00,640 - anthropic._base_client - DEBUG - request_id: req_011CNbdmd9JpjZUa4Rq2VVCH
# Adjusted SQL:
# Here is the modified SQL query based on the instructions:
#
# SELECT
#   a.region,
#   COUNT(DISTINCT a.agency_id) AS total_agencies,
#   SUM(p.premium_amount) AS total_premium,
#   SUM(p.premium_amount) / COUNT(DISTINCT a.agency_id) AS avg_premium_per_agency,
#   COUNT(p.policy_id) AS total_policies
# FROM
#   agencies a
#   JOIN agents ag ON a.agency_id = ag.agency_id
#   JOIN policies p ON ag.agent_id = p.agent_id
# WHERE
#   a.region = 'Northeast' -- active, lapsed, cancelled
#   AND p.status IN ('active', 'lapsed', 'cancelled')
# GROUP BY
#   a.region
# ORDER BY
#   total_premium DESC;

# %%
test_question_neg = "What is the average claim amount for auto policies?"

print(f"Processing question: '{test_question_neg}'")
response = assistant.process_question(test_question_4)

print(f"\nMatch found: {response.get('match_found', False)}")
print(f"Source: {response.get('source', 'unknown')}")

if not response.get('match_found', False):
    print("\nAI-generated SQL:")
    print(response.get('sql', ''))
    
    if 'ai_generated' in response and 'query_explanation' in response['ai_generated']:
        print("\nExplanation:")
        print(response['ai_generated']['query_explanation'])
# Out:
# 2025-04-28 13:11:09,867 - smart_assistant - INFO - Processing question: What is the average claim amount for auto policies?
# 2025-04-28 13:11:09,867 - INFO - Processing question: What is the average claim amount for auto policies?
# 2025-04-28 13:11:09,869 - smart_assistant - INFO - Created prompt with 5 queries
# 2025-04-28 13:11:09,869 - INFO - Created prompt with 5 queries
# 2025-04-28 13:11:09,869 - smart_assistant - DEBUG - Full queries text: Query 1:
# Name: Top Performing Agencies by Premium
# Question: Which agencies generate the most premium?
# SQL: SELECT
#   a.agency_id,
#   a.agency_name,
#   a.region,
#   a.tier,
#   SUM(p.premium_amount) AS total_premium
# FROM
#   agencies a
#   JOIN agents ag ON a.agency_id = ag.agency_id
#   JOIN policies p ON ag.agent_id = p.agent_id
# WHERE
#   p.status = 'active' -- active, lapsed, cancelled
# GROUP BY
#   a.agency_id, a.agency_name, a.region, a.tier
# ORDER BY
#   total_premium DESC
# LIMIT 10;
#
# Explanation: This query calculates the total premium amount generated by each agency. It joins the agencies, agents, and policies tables to aggregate premium amounts for active policies, then sorts them by total premium in descending order.
#
# Query 2:
# Name: Distribution Channel Performance Analysis
# Question: How are our different distribution channels performing?
# SQL: SELECT
#   dc.channel_id,
#   dc.channel_name,
#   dc.channel_type,
#   COUNT(p.policy_id) AS policy_count,
#   SUM(p.premium_amount) AS total_premium,
#   AVG(p.premium_amount) AS avg_premium_per_policy,
#   SUM(p.premium_amount * dc.commission_rate / 100) AS estimated_commission
# FROM
#   distribution_channels dc
#   JOIN policies p ON dc.channel_id = p.channel_id
# WHERE
#   p.status = 'active' -- active, lapsed, cancelled
# GROUP BY
#   dc.channel_id, dc.channel_name, dc.channel_type
# ORDER BY
#   total_premium DESC;
#
# Explanation: This query analyzes the performance of different distribution channels by measuring total premium, policy count, and average premium per policy for each channel. Only active policies are included, and the results are ordered by total premium.
#
# Query 3:
# Name: Agent Performance Report
# Question: How are our agents performing in terms of sales?
# SQL: SELECT
#   ag.agent_id,
#   ag.agent_name,
#   a.agency_name,
#   ag.certification_level,
#   COUNT(p.policy_id) AS policies_sold,
#   SUM(p.premium_amount) AS total_premium,
#   SUM(p.annual_revenue_impact) AS total_revenue_impact
# FROM
#   agents ag
#   JOIN agencies a ON ag.agency_id = a.agency_id
#   JOIN policies p ON ag.agent_id = p.agent_id
# WHERE
#   ag.status = 'active' -- active, inactive
#   AND p.status = 'active' -- active, lapsed, cancelled
# GROUP BY
#   ag.agent_id, ag.agent_name, a.agency_name, ag.certification_level
# ORDER BY
#   total_premium DESC;
#
# Explanation: This query provides a performance report for agents, including their agency, certification level, number of policies sold, total premium, and revenue impact. It only includes active agents and their active policies.
#
# Query 4:
# Name: Claims Analysis by Policy Type
# Question: What are our loss ratios by policy type?
# SQL: SELECT
#   p.policy_type,
#   COUNT(p.policy_id) AS policy_count,
#   SUM(p.premium_amount) AS total_premium,
#   COUNT(c.claim_id) AS claim_count,
#   SUM(c.claim_amount) AS total_claim_amount,
#   AVG(c.claim_amount) AS avg_claim_amount,
#   COUNT(c.claim_id)::float / COUNT(p.policy_id) AS claim_frequency,
#   CASE
#     WHEN SUM(p.premium_amount) > 0 THEN
#       SUM(c.claim_amount) / SUM(p.premium_amount) * 100
#     ELSE 0
#   END AS loss_ratio_percent
# FROM
#   policies p
#   LEFT JOIN claims c ON p.policy_id = c.policy_id
# WHERE
#   p.status = 'active' -- active, lapsed, cancelled
# GROUP BY
#   p.policy_type
# ORDER BY
#   loss_ratio_percent DESC;
#
# Explanation: This query analyzes claims data grouped by policy type, showing total claim amount, average claim amount, claim frequency, and loss ratio. The loss ratio is calculated as (total claim amount / total premium) for each policy type.
#
# Query 5:
# Name: Regional Agency Performance
# Question: How are our agencies performing by region?
# SQL: SELECT
#   a.region,
#   COUNT(DISTINCT a.agency_id) AS agency_count,
#   SUM(p.premium_amount) AS total_premium,
#   SUM(p.premium_amount) / COUNT(DISTINCT a.agency_id) AS avg_premium_per_agency,
#   COUNT(p.policy_id) AS policy_count
# FROM
#   agencies a
#   JOIN agents ag ON a.agency_id = ag.agency_id
#   JOIN policies p ON ag.agent_id = p.agent_id
# WHERE
#   p.status = 'active' -- active, lapsed, cancelled
# GROUP BY
#   a.region
# ORDER BY
#   total_premium DESC;
#
# Explanation: This query analyzes agency performance by region, showing the number of agencies, average premium per agency, total premium, and policy count for each region. The results are sorted by total premium in descending order.
#
#
# 2025-04-28 13:11:09,869 - DEBUG - Full queries text: Query 1:
# Name: Top Performing Agencies by Premium
# Question: Which agencies generate the most premium?
# SQL: SELECT
#   a.agency_id,
#   a.agency_name,
#   a.region,
#   a.tier,
#   SUM(p.premium_amount) AS total_premium
# FROM
#   agencies a
#   JOIN agents ag ON a.agency_id = ag.agency_id
#   JOIN policies p ON ag.agent_id = p.agent_id
# WHERE
#   p.status = 'active' -- active, lapsed, cancelled
# GROUP BY
#   a.agency_id, a.agency_name, a.region, a.tier
# ORDER BY
#   total_premium DESC
# LIMIT 10;
#
# Explanation: This query calculates the total premium amount generated by each agency. It joins the agencies, agents, and policies tables to aggregate premium amounts for active policies, then sorts them by total premium in descending order.
#
# Query 2:
# Name: Distribution Channel Performance Analysis
# Question: How are our different distribution channels performing?
# SQL: SELECT
#   dc.channel_id,
#   dc.channel_name,
#   dc.channel_type,
#   COUNT(p.policy_id) AS policy_count,
#   SUM(p.premium_amount) AS total_premium,
#   AVG(p.premium_amount) AS avg_premium_per_policy,
#   SUM(p.premium_amount * dc.commission_rate / 100) AS estimated_commission
# FROM
#   distribution_channels dc
#   JOIN policies p ON dc.channel_id = p.channel_id
# WHERE
#   p.status = 'active' -- active, lapsed, cancelled
# GROUP BY
#   dc.channel_id, dc.channel_name, dc.channel_type
# ORDER BY
#   total_premium DESC;
#
# Explanation: This query analyzes the performance of different distribution channels by measuring total premium, policy count, and average premium per policy for each channel. Only active policies are included, and the results are ordered by total premium.
#
# Query 3:
# Name: Agent Performance Report
# Question: How are our agents performing in terms of sales?
# SQL: SELECT
#   ag.agent_id,
#   ag.agent_name,
#   a.agency_name,
#   ag.certification_level,
#   COUNT(p.policy_id) AS policies_sold,
#   SUM(p.premium_amount) AS total_premium,
#   SUM(p.annual_revenue_impact) AS total_revenue_impact
# FROM
#   agents ag
#   JOIN agencies a ON ag.agency_id = a.agency_id
#   JOIN policies p ON ag.agent_id = p.agent_id
# WHERE
#   ag.status = 'active' -- active, inactive
#   AND p.status = 'active' -- active, lapsed, cancelled
# GROUP BY
#   ag.agent_id, ag.agent_name, a.agency_name, ag.certification_level
# ORDER BY
#   total_premium DESC;
#
# Explanation: This query provides a performance report for agents, including their agency, certification level, number of policies sold, total premium, and revenue impact. It only includes active agents and their active policies.
#
# Query 4:
# Name: Claims Analysis by Policy Type
# Question: What are our loss ratios by policy type?
# SQL: SELECT
#   p.policy_type,
#   COUNT(p.policy_id) AS policy_count,
#   SUM(p.premium_amount) AS total_premium,
#   COUNT(c.claim_id) AS claim_count,
#   SUM(c.claim_amount) AS total_claim_amount,
#   AVG(c.claim_amount) AS avg_claim_amount,
#   COUNT(c.claim_id)::float / COUNT(p.policy_id) AS claim_frequency,
#   CASE
#     WHEN SUM(p.premium_amount) > 0 THEN
#       SUM(c.claim_amount) / SUM(p.premium_amount) * 100
#     ELSE 0
#   END AS loss_ratio_percent
# FROM
#   policies p
#   LEFT JOIN claims c ON p.policy_id = c.policy_id
# WHERE
#   p.status = 'active' -- active, lapsed, cancelled
# GROUP BY
#   p.policy_type
# ORDER BY
#   loss_ratio_percent DESC;
#
# Explanation: This query analyzes claims data grouped by policy type, showing total claim amount, average claim amount, claim frequency, and loss ratio. The loss ratio is calculated as (total claim amount / total premium) for each policy type.
#
# Query 5:
# Name: Regional Agency Performance
# Question: How are our agencies performing by region?
# SQL: SELECT
#   a.region,
#   COUNT(DISTINCT a.agency_id) AS agency_count,
#   SUM(p.premium_amount) AS total_premium,
#   SUM(p.premium_amount) / COUNT(DISTINCT a.agency_id) AS avg_premium_per_agency,
#   COUNT(p.policy_id) AS policy_count
# FROM
#   agencies a
#   JOIN agents ag ON a.agency_id = ag.agency_id
#   JOIN policies p ON ag.agent_id = p.agent_id
# WHERE
#   p.status = 'active' -- active, lapsed, cancelled
# GROUP BY
#   a.region
# ORDER BY
#   total_premium DESC;
#
# Explanation: This query analyzes agency performance by region, showing the number of agencies, average premium per agency, total premium, and policy count for each region. The results are sorted by total premium in descending order.
#
#
# 2025-04-28 13:11:09,870 - smart_assistant - INFO - Sending request to LLM service...
# 2025-04-28 13:11:09,870 - INFO - Sending request to LLM service...
# Processing question: 'What is the average claim amount for auto policies?'
# 2025-04-28 13:11:10,912 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-04-28 13:11:10,916 - smart_assistant - INFO - Received response from LLM service
# 2025-04-28 13:11:10,916 - INFO - Received response from LLM service
# 2025-04-28 13:11:10,918 - smart_assistant - DEBUG - Raw LLM response: {
#   "match": true,
#   "query_number": 4,
#   "similarity": 90,
#   "modification_needed": true,
#   "modifications": "Change policy_type from 'auto' to 'auto' in WHERE clause"
# }
# 2025-04-28 13:11:10,918 - DEBUG - Raw LLM response: {
#   "match": true,
#   "query_number": 4,
#   "similarity": 90,
#   "modification_needed": true,
#   "modifications": "Change policy_type from 'auto' to 'auto' in WHERE clause"
# }
# 2025-04-28 13:11:10,919 - smart_assistant - INFO - Match found! Query #4 with 90% similarity
# 2025-04-28 13:11:10,919 - INFO - Match found! Query #4 with 90% similarity
# 2025-04-28 13:11:10,919 - smart_assistant - INFO - Found matching query: Claims Analysis by Policy Type with 90% similarity
# 2025-04-28 13:11:10,919 - INFO - Found matching query: Claims Analysis by Policy Type with 90% similarity
# 2025-04-28 13:11:10,920 - smart_assistant - INFO - Modifications needed: Change policy_type from 'auto' to 'auto' in WHERE clause
# 2025-04-28 13:11:10,920 - INFO - Modifications needed: Change policy_type from 'auto' to 'auto' in WHERE clause
# 2025-04-28 13:11:10,921 - smart_assistant - INFO - Original SQL:
# SELECT
#   p.policy_type,
#   COUNT(p.policy_id) AS policy_count,
#   SUM(p.premium_amount) AS total_premium,
#   COUNT(c.claim_id) AS claim_count,
#   SUM(c.claim_amount) AS total_claim_amount,
#   AVG(c.claim_amount) AS avg_claim_amount,
#   COUNT(c.claim_id)::float / COUNT(p.policy_id) AS claim_frequency,
#   CASE
#     WHEN SUM(p.premium_amount) > 0 THEN
#       SUM(c.claim_amount) / SUM(p.premium_amount) * 100
#     ELSE 0
#   END AS loss_ratio_percent
# FROM
#   policies p
#   LEFT JOIN claims c ON p.policy_id = c.policy_id
# WHERE
#   p.status = 'active' -- active, lapsed, cancelled
# GROUP BY
#   p.policy_type
# ORDER BY
#   loss_ratio_percent DESC;
#
# 2025-04-28 13:11:10,921 - INFO - Original SQL:
# SELECT
#   p.policy_type,
#   COUNT(p.policy_id) AS policy_count,
#   SUM(p.premium_amount) AS total_premium,
#   COUNT(c.claim_id) AS claim_count,
#   SUM(c.claim_amount) AS total_claim_amount,
#   AVG(c.claim_amount) AS avg_claim_amount,
#   COUNT(c.claim_id)::float / COUNT(p.policy_id) AS claim_frequency,
#   CASE
#     WHEN SUM(p.premium_amount) > 0 THEN
#       SUM(c.claim_amount) / SUM(p.premium_amount) * 100
#     ELSE 0
#   END AS loss_ratio_percent
# FROM
#   policies p
#   LEFT JOIN claims c ON p.policy_id = c.policy_id
# WHERE
#   p.status = 'active' -- active, lapsed, cancelled
# GROUP BY
#   p.policy_type
# ORDER BY
#   loss_ratio_percent DESC;
#
# 2025-04-28 13:11:10,922 - smart_assistant - WARNING - System prompt file not found: /Users/avenugopal/smart_query_assistant/app/adjust_sql_system_prompt.txt
# 2025-04-28 13:11:10,922 - WARNING - System prompt file not found: /Users/avenugopal/smart_query_assistant/app/adjust_sql_system_prompt.txt
# 2025-04-28 13:11:10,922 - smart_assistant - WARNING - User prompt file not found: /Users/avenugopal/smart_query_assistant/app/adjust_sql_user_prompt.txt
# 2025-04-28 13:11:10,922 - WARNING - User prompt file not found: /Users/avenugopal/smart_query_assistant/app/adjust_sql_user_prompt.txt
# 2025-04-28 13:11:10,923 - smart_assistant - INFO - Adjusting SQL query
# 2025-04-28 13:11:10,923 - INFO - Adjusting SQL query
# 2025-04-28 13:11:13,473 - INFO - HTTP Request: POST https://api.anthropic.com/v1/messages "HTTP/1.1 200 OK"
# 2025-04-28 13:11:13,476 - smart_assistant - INFO - Adjusted SQL:
# Here is the modified SQL query:
#
# SELECT
#   p.policy_type,
#   COUNT(p.policy_id) AS total_policies,
#   SUM(p.premium_amount) AS total_premium,
#   COUNT(c.claim_id) AS total_claims,
#   SUM(c.claim_amount) AS total_claim_amount,
#   AVG(c.claim_amount) AS average_claim_amount,
#   COUNT(c.claim_id)::float / COUNT(p.policy_id) AS claim_frequency,
#   CASE
#     WHEN SUM(p.premium_amount) > 0 THEN
#       SUM(c.claim_amount) / SUM(p.premium_amount) * 100
#     ELSE 0
#   END AS loss_ratio_percent
# FROM
#   policies p
#   LEFT JOIN claims c ON p.policy_id = c.policy_id
# WHERE
#   p.policy_type = 'auto' -- active, lapsed, cancelled
#   AND p.status = 'active'
# GROUP BY
#   p.policy_type
# ORDER BY
#   loss_ratio_percent DESC;
# 2025-04-28 13:11:13,476 - INFO - Adjusted SQL:
# Here is the modified SQL query:
#
# SELECT
#   p.policy_type,
#   COUNT(p.policy_id) AS total_policies,
#   SUM(p.premium_amount) AS total_premium,
#   COUNT(c.claim_id) AS total_claims,
#   SUM(c.claim_amount) AS total_claim_amount,
#   AVG(c.claim_amount) AS average_claim_amount,
#   COUNT(c.claim_id)::float / COUNT(p.policy_id) AS claim_frequency,
#   CASE
#     WHEN SUM(p.premium_amount) > 0 THEN
#       SUM(c.claim_amount) / SUM(p.premium_amount) * 100
#     ELSE 0
#   END AS loss_ratio_percent
# FROM
#   policies p
#   LEFT JOIN claims c ON p.policy_id = c.policy_id
# WHERE
#   p.policy_type = 'auto' -- active, lapsed, cancelled
#   AND p.status = 'active'
# GROUP BY
#   p.policy_type
# ORDER BY
#   loss_ratio_percent DESC;
# Match found: True
# Source: verified
